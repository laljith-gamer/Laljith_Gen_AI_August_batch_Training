# %% [markdown]
# # SmartHire GenAI — 03: Career Mentor RAG Prototype
# Prototypes grounded question answering over the career notes corpus with strict anti-hallucination refusal.

# %%
import sys
sys.path.append('..')
from src.mentor.rag_chain import CareerMentorRAG
from src.safety.guardrails import SafetyGuardrails

mentor = CareerMentorRAG()
print('Career Mentor RAG initialized.')
# Out:
# Career Mentor RAG initialized.

# %%
query = 'How do I transition from software engineering into Machine Learning?'
safe, reason = SafetyGuardrails.evaluate_input(query)
print(f'Guardrail check: {"SAFE" if safe else f"BLOCKED: {reason}"}')

if safe:
    response = mentor.answer_question(query)
    print('\n--- Grounded Answer ---\n', response.answer)
    print('\n--- Citations ---\n', [c.document_title for c in response.citations])
# Out:
# Guardrail check: SAFE
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# --- Grounded Answer ---
#  To transition from software engineering into Machine Learning (ML), you can leverage your existing programming foundation and systematically build your skills across mathematics, ML frameworks, generative AI, and production deployment.
#
# Based on the SmartHire career knowledge base, here is a practical roadmap to guide your transition:
#
# ### 1. Understand the Role of an ML Engineer
# As a software engineer, your transition will focus on bridging the gap between research models and production applications. Your core responsibilities will shift toward:
# *   Building training and automated feature pipelines.
# *   Fine-tuning foundation models.
# *   Deploying inference endpoints and monitoring model drift in production.
#
# ### 2. Master the Core Technical Skills
# You will need to expand your technical toolkit in three primary areas:
# *   **Mathematics & Statistics:** Develop a strong grasp of linear algebra (eigenvalues, matrix decomposition), multivariate calculus (gradients, backpropagation), probability distributions, and optimization algorithms (SGD, AdamW).
# *   **Frameworks & Libraries:** Master core libraries such as NumPy, Pandas, Scikit-Learn, PyTorch, TensorFlow, and Hugging Face Transformers.
# *   **Generative AI & LLM Systems:** Learn prompt engineering, Retrieval-Augmented Generation (RAG), vector databases (such as FAISS and Chroma), tokenization, LangChain, and semantic search.
#
# ### 3. Follow the Recommended Transition Pathway
# To build practical, portfolio-ready experience, follow these sequential steps:
# *   **Start with Classical ML:** Master classical supervised and unsupervised ML algorithms in Scikit-Learn before diving into complex deep learning.
# *   **Build a Generative AI Project:** Construct a full RAG pipeline using FAISS, embeddings, and a modern LLM (such as Gemini 3.8 Flash), ensuring you demonstrate grounded source citations.
# *   **Apply Software Engineering Best Practices:** Package your model's inference into a Dockerized FastAPI service, complete with rate limits and health check endpoints.
#
# ### 4. Learn Production MLOps Tools
# To align with industry expectations (such as those for enterprise roles in fraud detection or risk modeling), you should gain experience with:
# *   **ML Lifecycle Management:** Tracking and managing models using tools like MLflow.
# *   **Cloud & Deployment:** Deploying and maintaining models on cloud platforms like AWS (specifically AWS SageMaker) and containerizing applications using Docker.
#
# ---
#
# Based on:
# - machine_learning_roadmap.txt (Machine Learning Roadmap)
# - job_JOB_102.txt (Job Posting: Machine Learning Engineer (Quantum Analytics))
#
# --- Citations ---
#  ['Machine Learning Roadmap', 'Machine Learning Roadmap', 'Machine Learning Roadmap', 'Job Posting: Machine Learning Engineer (Quantum Analytics)']

# %%
unsupported_query = 'What is the exact internal travel reimbursement limit for Acme Widgets in 2029?'
resp = mentor.answer_question(unsupported_query)
print('Unsupported Query Answer:\n', resp.answer)
refused = any(term in resp.answer.lower() for term in ["don't know", 'not found', 'does not contain'])
print('Strict refusal enforced:', refused)
# Out:
# Unsupported Query Answer:
#  I don't know based on the available documents.
#
# Based on:
# - None of the provided documents contain information regarding Acme Widgets or travel reimbursement limits.
# Strict refusal enforced: True
