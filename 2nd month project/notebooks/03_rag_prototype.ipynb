# %% [markdown]
# # SmartHire GenAI — 03: Career Mentor RAG Prototype
# Prototypes grounded question answering over the career notes corpus with strict anti-hallucination refusal.

# %%
import sys
sys.path.append('..')
from src.mentor.rag_chain import CareerMentorRAG
from src.safety.guardrails import SafetyGuardrails

mentor = CareerMentorRAG()
print('Career Mentor RAG initialized.')
# Out:
# Career Mentor RAG initialized.

# %%
query = 'How do I transition from software engineering into Machine Learning?'
safe, reason = SafetyGuardrails.evaluate_input(query)
print(f'Guardrail check: {"SAFE" if safe else f"BLOCKED: {reason}"}')

if safe:
    response = mentor.answer_question(query)
    print('\n--- Grounded Answer ---\n', response.answer)
    print('\n--- Citations ---\n', [c.document_title for c in response.citations])
# Out:
# Guardrail check: SAFE
#
# --- Grounded Answer ---
#  To transition from software engineering into Machine Learning (ML), you can leverage your existing software development background while systematically building your mathematical, algorithmic, and system-deployment skills.
#
# Based on the SmartHire career knowledge base, here is a practical, step-by-step roadmap to guide your transition:
#
# ### 1. Master the Core Technical Skills
# To bridge the gap between software engineering and ML, you need to build a strong foundation in three key areas:
# *   **Mathematics & Statistics:** Focus on linear algebra (eigenvalues, matrix decomposition), multivariate calculus (gradients, backpropagation), probability distributions, and optimization algorithms (such as SGD and AdamW).
# *   **Frameworks & Libraries:** Develop proficiency in Python, NumPy, Pandas, Scikit-Learn, PyTorch, TensorFlow, and Hugging Face Transformers.
# *   **Generative AI & LLM Systems:** Learn prompt engineering, Retrieval-Augmented Generation (RAG), vector databases (such as FAISS and Chroma), tokenization, LangChain, and semantic search.
#
# ### 2. Follow a Structured Learning Pathway
# When transitioning, avoid jumping straight into complex deep learning. Instead, follow this progression:
# *   **Start with Classical ML:** Master classical supervised and unsupervised machine learning algorithms in Scikit-Learn before diving into deep learning.
# *   **Build Practical GenAI Projects:** Build a full RAG (Retrieval-Augmented Generation) pipeline using FAISS, embeddings, and a modern LLM (e.g., Gemini 3.8 Flash) that demonstrates grounded source citations.
# *   **Leverage Your Engineering Skills:** Package your model's inference into a Dockerized FastAPI service complete with rate limits and health check endpoints. This highlights your ability to write production-ready code.
#
# ### 3. Understand the Core Responsibilities of the Role
# As an ML Engineer, your job is to bridge the gap between research models and production applications. Your day-to-day responsibilities will include:
# *   Building training pipelines.
# *   Fine-tuning foundation models.
# *   Deploying inference endpoints.
# *   Monitoring model drift in production.
#
# ### 4. Align with Industry Job Requirements
# To make yourself competitive for roles (such as the Machine Learning Engineer position at Quantum Analytics), you should also gain experience in:
# *   **MLOps & Lifecycle Management:** Learn to manage the ML lifecycle using tools like MLflow and build automated feature pipelines.
# *   **Cloud Platforms:** Get comfortable deploying and monitoring production machine learning models on cloud platforms like AWS (specifically AWS SageMaker) for real-world use cases like risk modeling or fraud detection.
#
# ***
#
# Based on:
# - machine_learning_roadmap.txt (Machine Learning Roadmap)
# - job_JOB_102.txt (Job Posting: Machine Learning Engineer (Quantum Analytics))
#
# --- Citations ---
#  ['Machine Learning Roadmap', 'Machine Learning Roadmap', 'Machine Learning Roadmap', 'Job Posting: Machine Learning Engineer (Quantum Analytics)']
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
unsupported_query = 'What is the exact internal travel reimbursement limit for Acme Widgets in 2029?'
resp = mentor.answer_question(unsupported_query)
print('Unsupported Query Answer:\n', resp.answer)
refused = any(term in resp.answer.lower() for term in ["don't know", 'not found', 'does not contain'])
print('Strict refusal enforced:', refused)
# Out:
# Unsupported Query Answer:
#  I don't know based on the available documents.
# Strict refusal enforced: True
