# %% [markdown]
# # SmartHire GenAI — 03: Career Mentor RAG Prototype
# Prototypes grounded question answering over the career notes corpus with strict anti-hallucination refusal.

# %%
import sys
sys.path.append('..')
from src.mentor.rag_chain import CareerMentorRAG
from src.safety.guardrails import SafetyGuardrails

mentor = CareerMentorRAG()
print('Career Mentor RAG initialized.')
# Out:
# Career Mentor RAG initialized.

# %%
query = 'How do I transition from software engineering into Machine Learning?'
safe, reason = SafetyGuardrails.evaluate_input(query)
print(f'Guardrail check: {"SAFE" if safe else f"BLOCKED: {reason}"}')

if safe:
    response = mentor.answer_question(query)
    print('\n--- Grounded Answer ---\n', response.answer)
    print('\n--- Citations ---\n', [c.document_title for c in response.citations])
# Out:
# Guardrail check: SAFE
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Retrying RAG generation with fallback gemini-3.6-flash...
# Gemini RAG call encountered error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.6-flash\nPlease retry in 27.526052417s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.6-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}. Using deterministic grounded response.
# --- Grounded Answer ---
#  Based on the SmartHire knowledge base:
#
# ## Transition Pathway
# - Master classical supervised and unsupervised ML algorithms in Scikit-Learn before diving into deep learning.
# - Build a full RAG pipeline using FAISS, embeddings, and a modern LLM (e.g. Gemini 3.8 Flash), demonstrating grounded source citations.
# - Package inference into a Dock
#
# To pursue this pathway, review the full recommendations in machine_learning_roadmap.txt.
#
# Based on:
# - Machine Learning Roadmap
# - Machine Learning Roadmap
# - Machine Learning Roadmap
# - Job Posting: Machine Learning Engineer (Quantum Analytics)
#
# --- Citations ---
#  ['Machine Learning Roadmap', 'Machine Learning Roadmap', 'Machine Learning Roadmap', 'Job Posting: Machine Learning Engineer (Quantum Analytics)']

# %%
unsupported_query = 'What is the exact internal travel reimbursement limit for Acme Widgets in 2029?'
resp = mentor.answer_question(unsupported_query)
print('Unsupported Query Answer:\n', resp.answer)
refused = any(term in resp.answer.lower() for term in ["don't know", 'not found', 'does not contain'])
print('Strict refusal enforced:', refused)
# Out:
# Retrying RAG generation with fallback gemini-3.6-flash...
# Gemini RAG call encountered error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.6-flash\nPlease retry in 24.037741728s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.6-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}. Using deterministic grounded response.
# Unsupported Query Answer:
#  Based on the SmartHire knowledge base:
#
# ## Transition Pathway
# - Master classical supervised and unsupervised ML algorithms in Scikit-Learn before diving into deep learning.
# - Build a full RAG pipeline using FAISS, embeddings, and a modern LLM (e.g. Gemini 3.8 Flash), demonstrating grounded source citations.
# - Package inference into a Dock
#
# To pursue this pathway, review the full recommendations in machine_learning_roadmap.txt.
#
# Based on:
# - Machine Learning Roadmap
# - Interview Preparation Guide
# - Job Posting: LLM & RAG Systems Researcher (Cerebral Minds)
# - Data Analyst Roadmap
# Strict refusal enforced: False
